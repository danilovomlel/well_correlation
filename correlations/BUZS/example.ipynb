# %%
import sys
import os
import pandas as pd

curr_dir = os.getcwd()
parent_dir = os.path.abspath(os.path.join(curr_dir, '../..'))
sys.path.append(parent_dir)

# %%
import utils.read_data
import utils.view_markers
import utils.onduletas
from data.bacias.BUZS.buzs import MINOR_BUZ

from importlib import reload
reload(utils.onduletas)
reload(utils.read_data)
reload(utils.view_markers)

from utils.onduletas import interpolate_wells
from utils.read_data import las2csv, read_csv
from utils.view_markers import show_markers

# %%
markers_path = "C:/Users\danil\Downloads\PROGRAMAS\Correlacao_DTW\data/Marcadores.csv"
markers = pd.read_csv(markers_path).set_index("POÇOS")

# %%
path = "C:/Users\danil\Downloads\PROGRAMAS\Correlacao_DTW\data\well_logs\Buzios"
csv_path = os.path.join(path, "CSV")

las2csv(path)
data_corr = read_csv(csv_path, wells=MINOR_BUZ )

# %%
data_corr['3-BRSA-1243-RJS_0']
# Out:
#           DEPTH  GR
# 0     5313.1974 NaN
# 1     5313.2736 NaN
# 2     5313.3498 NaN
# 3     5313.4260 NaN
# 4     5313.5022 NaN
# ...         ...  ..
# 7113  5855.2080 NaN
# 7114  5855.2842 NaN
# 7115  5855.3604 NaN
# 7116  5855.4366 NaN
# 7117  5855.5128 NaN
#
# [7118 rows x 2 columns]

# %%
interpolate_wells(data_corr, step=0.3)

# %%
data_corr['3-BRSA-1243-RJS_0']
# Out:
#           DEPTH  GR
# 0     5313.1974 NaN
# 1     5313.4974 NaN
# 2     5313.7974 NaN
# 3     5314.0974 NaN
# 4     5314.3974 NaN
# ...         ...  ..
# 1803  5854.0974 NaN
# 1804  5854.3974 NaN
# 1805  5854.6974 NaN
# 1806  5854.9974 NaN
# 1807  5855.2974 NaN
#
# [1808 rows x 2 columns]

# %%
_ = show_markers(data_corr, markers, figsize=(20,10))
